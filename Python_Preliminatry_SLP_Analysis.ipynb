# %% [markdown]
# <a href="https://colab.research.google.com/github/y0y0l0/HHA506/blob/main/Python_Preliminatry_SLP_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#drop row 1 and row 2 from the dataframe using list
df = pd.read_csv('slpdata_numerical.csv', header='infer')
#df = pd.read_csv('slpdata_numerical.csv', header='infer', skiprows=[1,2])
df_clean =df.drop ([0,1])

# %%
#view all columns and row counts
df.shape
#view all columns in dataframe
list(df)
df_simple = df_clean[[
'ResponseId',
 'Q1',
 'Q2',
 'Q4',
 'Q5',
 'Q6',
 'Q7',
 'Q8',
 'Q9',
 'Q10',
 'Q11',
 'Q12',
 'Q13_1',
 'Q13_2',
 'Q13_3',
 'Q13_4']]
#df_simple

# %%
df_simple = df_simple.set_index("ResponseId")
df_simple
# Out:
#                   Q1 Q2 Q4 Q5 Q6 Q7 Q8 Q9 Q10 Q11 Q12 Q13_1 Q13_2 Q13_3 Q13_4
# ResponseId
# R_6fn5ekDobUP1m5g  4  3  1  2  2  3  3  3   2   2   4     1     4     5     3
# R_3KR0mBnSZdjoJAa  1  1  5  3  2  1  3  3   1   2   4     3     2     1     1
# R_5gqVnk14OjcBmXI  4  3  4  4  2  3  3  3   2   1   4     4     3     3     4
# R_0HUEeMmeNFs5WZw  3  3  2  2  4  1  1  1   3   4   5     1     2     5     4
# R_7TYgOzdHL53Y5Ho  1  3  1  3  2  1  4  1   2   3   4     3     4     3     5
# ...               .. .. .. .. .. .. .. ..  ..  ..  ..   ...   ...   ...   ...
# R_8x0fqyHU55k51Eq  4  1  2  3  1  2  5  3   3   2   5     3     3     1     1
# R_72OeMk6x3Bgz7AG  2  3  4  5  2  2  1  1   2   4   2     4     3     1     2
# R_2rzg4pqMXolgfbg  1  1  4  2  1  1  5  1   3   3   2     3     2     3     2
# R_6G9pvj6waxWi4RM  3  2  5  1  5  3  3  1   1   2   2     5     2     4     4
# R_9GEi9QDgBzaApEi  1  2  1  5  1  1  1  1   2   3   2     3     2     4     5
#
# ...

# %%
#create a index
df_simple = df_simple.set_index("ResponseId")
df_simple
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1417306833.py in <cell line: 0>()
#       1 #create a index
# ----> 2 df_simple = df_simple.set_index("ResponseId")
#       3 df_simple
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['ResponseId'] are in the columns"

# %%
df_simple = df_simple.astype(int)
df_simple
# Out:
#                    Q1  Q2  Q4  Q5  Q6  Q7  Q8  Q9  Q10  Q11  Q12  Q13_1  \
# ResponseId
# R_6fn5ekDobUP1m5g   4   3   1   2   2   3   3   3    2    2    4      1
# R_3KR0mBnSZdjoJAa   1   1   5   3   2   1   3   3    1    2    4      3
# R_5gqVnk14OjcBmXI   4   3   4   4   2   3   3   3    2    1    4      4
# R_0HUEeMmeNFs5WZw   3   3   2   2   4   1   1   1    3    4    5      1
# R_7TYgOzdHL53Y5Ho   1   3   1   3   2   1   4   1    2    3    4      3
# ...                ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...    ...
# R_8x0fqyHU55k51Eq   4   1   2   3   1   2   5   3    3    2    5      3
# R_72OeMk6x3Bgz7AG   2   3   4   5   2   2   1   1    2    4    2      4
# R_2rzg4pqMXolgfbg   1   1   4   2   1   1   5   1    3    3    2      3
# R_6G9pvj6waxWi4RM   3   2   5   1   5   3   3   1    1    2    2      5
# R_9GEi9QDgBzaApEi   1   2   1   5   1   1   1   1    2    3    2      3
#
#                    Q13_2  Q13_3  Q13_4
# ResponseId
# ...

# %%
# Select only the columns that should be integers
integer_cols = ['Q1', 'Q2', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8', 'Q9', 'Q10', 'Q11', 'Q12', 'Q13_1', 'Q13_2', 'Q13_3', 'Q13_4']

# Convert only these columns to int
df_simple[integer_cols] = df_simple[integer_cols].astype(int)

df_simple
# Out:
#                    Q1  Q2  Q4  Q5  Q6  Q7  Q8  Q9  Q10  Q11  Q12  Q13_1  \
# ResponseId
# R_6fn5ekDobUP1m5g   4   3   1   2   2   3   3   3    2    2    4      1
# R_3KR0mBnSZdjoJAa   1   1   5   3   2   1   3   3    1    2    4      3
# R_5gqVnk14OjcBmXI   4   3   4   4   2   3   3   3    2    1    4      4
# R_0HUEeMmeNFs5WZw   3   3   2   2   4   1   1   1    3    4    5      1
# R_7TYgOzdHL53Y5Ho   1   3   1   3   2   1   4   1    2    3    4      3
# ...                ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...    ...
# R_8x0fqyHU55k51Eq   4   1   2   3   1   2   5   3    3    2    5      3
# R_72OeMk6x3Bgz7AG   2   3   4   5   2   2   1   1    2    4    2      4
# R_2rzg4pqMXolgfbg   1   1   4   2   1   1   5   1    3    3    2      3
# R_6G9pvj6waxWi4RM   3   2   5   1   5   3   3   1    1    2    2      5
# R_9GEi9QDgBzaApEi   1   2   1   5   1   1   1   1    2    3    2      3
#
#                    Q13_2  Q13_3  Q13_4
# ResponseId
# ...

# %%
df_simple['Q1'].describe()
#df_simple = df_simple.astype(int)
#df_simple['Q1'].describe()
for col in df_simple.columns:
    print(col)
    print(df_simple[col].describe())

    df_simple.to_csv('slpdata_numerical_Questions_Only.csv')
    #this will make the size of the file smaller
    #df_simple.to_parquet('slpdata_numerical_Questions_Only.parquet')
    #df_simple.to_sql('slpdata_numerical_Questions_Only', con=engine)
# Out:
# Q1
# count    1100.000000
# mean        3.053636
# std         1.426333
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Q1, dtype: float64
# Q2
# count    1100.000000
# mean        2.027273
# std         0.820119
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         3.000000
# Name: Q2, dtype: float64
# Q4
# count    1100.000000
# mean        2.943636
# std         1.413733
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Q4, dtype: float64
# Q5
# count    1100.000000
# mean        3.022727
# std         1.459315
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Q5, dtype: float64
# Q6
# count    1100.000000
# mean        2.916364
# std         1.407863
# min         1.000000
# 25%         2.000000
# ...

# %%
recode_dict_v1 = {
    1: 3,
    2: 1,
    3: 2
}## recode_dict_v1

recode_dict_v2 = {
    1: 1,
    4: 1,
    5: 1,
    3: 2,
    2: 2
}## recode_dict_v2


df_simple_recode = df_simple.copy()
df_simple_recode["Q7"] = df_simple_recode["Q7"].map(recode_dict_v1)
df_simple_recode["Q9"] = df_simple_recode["Q9"].map(recode_dict_v1)
df_simple_recode["Q10"] = df_simple_recode["Q10"].map(recode_dict_v1)
df_simple_recode["Q11"] = df_simple_recode["Q11"].map(recode_dict_v2)
df_simple
df_simple_recode
# Out:
#                    Q1  Q2  Q4  Q5  Q6  Q7  Q8  Q9  Q10  Q11  Q12  Q13_1  \
# ResponseId
# R_6fn5ekDobUP1m5g   4   3   1   2   2   2   3   2    1    2    4      1
# R_3KR0mBnSZdjoJAa   1   1   5   3   2   3   3   2    3    2    4      3
# R_5gqVnk14OjcBmXI   4   3   4   4   2   2   3   2    1    1    4      4
# R_0HUEeMmeNFs5WZw   3   3   2   2   4   3   1   3    2    1    5      1
# R_7TYgOzdHL53Y5Ho   1   3   1   3   2   3   4   3    1    2    4      3
# ...                ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...    ...
# R_8x0fqyHU55k51Eq   4   1   2   3   1   1   5   2    2    2    5      3
# R_72OeMk6x3Bgz7AG   2   3   4   5   2   1   1   3    1    1    2      4
# R_2rzg4pqMXolgfbg   1   1   4   2   1   3   5   3    2    2    2      3
# R_6G9pvj6waxWi4RM   3   2   5   1   5   2   3   3    3    2    2      5
# R_9GEi9QDgBzaApEi   1   2   1   5   1   3   1   3    1    2    2      3
#
#                    Q13_2  Q13_3  Q13_4
# ResponseId
# ...

# %%
df_simple_recode['total_score'] = df_simple_recode.sum(axis=1)
#q2,4,5,12,13 - summation for environment_satisfaction
df_simple_recode['Environmental_satisfaction'] = df_simple_recode[['Q2',	'Q4',	'Q5' ,'Q12',	'Q13_1',	'Q13_2',	'Q13_3',	'Q13_4']].sum(axis=1)
df_simple_recode
# Out:
#                    Q1  Q2  Q4  Q5  Q6  Q7  Q8  Q9  Q10  Q11  Q12  Q13_1  \
# ResponseId
# R_6fn5ekDobUP1m5g   4   3   1   2   2   2   3   2    1    2    4      1
# R_3KR0mBnSZdjoJAa   1   1   5   3   2   3   3   2    3    2    4      3
# R_5gqVnk14OjcBmXI   4   3   4   4   2   2   3   2    1    1    4      4
# R_0HUEeMmeNFs5WZw   3   3   2   2   4   3   1   3    2    1    5      1
# R_7TYgOzdHL53Y5Ho   1   3   1   3   2   3   4   3    1    2    4      3
# ...                ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...    ...
# R_8x0fqyHU55k51Eq   4   1   2   3   1   1   5   2    2    2    5      3
# R_72OeMk6x3Bgz7AG   2   3   4   5   2   1   1   3    1    1    2      4
# R_2rzg4pqMXolgfbg   1   1   4   2   1   3   5   3    2    2    2      3
# R_6G9pvj6waxWi4RM   3   2   5   1   5   2   3   3    3    2    2      5
# R_9GEi9QDgBzaApEi   1   2   1   5   1   3   1   3    1    2    2      3
#
#                    Q13_2  Q13_3  Q13_4  total_score  \
# ResponseId
# ...

# %%
df_simple_recode['total_score'] = df_simple_recode.sum(axis=1)
df_simple_recode
# Out:
#                    Q1  Q2  Q4  Q5  Q6  Q7  Q8  Q9  Q10  Q11  Q12  Q13_1  \
# ResponseId
# R_6fn5ekDobUP1m5g   4   3   1   2   2   2   3   2    1    2    4      1
# R_3KR0mBnSZdjoJAa   1   1   5   3   2   3   3   2    3    2    4      3
# R_5gqVnk14OjcBmXI   4   3   4   4   2   2   3   2    1    1    4      4
# R_0HUEeMmeNFs5WZw   3   3   2   2   4   3   1   3    2    1    5      1
# R_7TYgOzdHL53Y5Ho   1   3   1   3   2   3   4   3    1    2    4      3
# ...                ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...    ...
# R_8x0fqyHU55k51Eq   4   1   2   3   1   1   5   2    2    2    5      3
# R_72OeMk6x3Bgz7AG   2   3   4   5   2   1   1   3    1    1    2      4
# R_2rzg4pqMXolgfbg   1   1   4   2   1   3   5   3    2    2    2      3
# R_6G9pvj6waxWi4RM   3   2   5   1   5   2   3   3    3    2    2      5
# R_9GEi9QDgBzaApEi   1   2   1   5   1   3   1   3    1    2    2      3
#
#                    Q13_2  Q13_3  Q13_4  total_score  \
# ResponseId
# ...

# %%
df_simple_recode['Routines_Statistics'] = df_simple_recode[['Q8', 'Q10']].sum(axis=1)

# %%
df_simple_recode['Training_quality_Statistics'] = df_simple_recode[['Q1', 'Q2', 'Q9', 'Q10']].sum(axis=1)

# %%
df_simple_Stats = df_simple_recode[['Environmental_satisfaction','Routines_Statistics','Training_quality_Statistics']]
df_simple_Stats
# Out:
#                    Environmental_satisfaction  Routines_Statistics  \
# ResponseId
# R_6fn5ekDobUP1m5g                          23                    4
# R_3KR0mBnSZdjoJAa                          20                    6
# R_5gqVnk14OjcBmXI                          29                    4
# R_0HUEeMmeNFs5WZw                          24                    3
# R_7TYgOzdHL53Y5Ho                          26                    5
# ...                                       ...                  ...
# R_8x0fqyHU55k51Eq                          19                    7
# R_72OeMk6x3Bgz7AG                          24                    2
# R_2rzg4pqMXolgfbg                          19                    7
# R_6G9pvj6waxWi4RM                          25                    6
# R_9GEi9QDgBzaApEi                          24                    2
#
#                    Training_quality_Statistics
# ResponseId
# R_6fn5ekDobUP1m5g                           10
# ...
